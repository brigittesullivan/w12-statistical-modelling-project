# %% [markdown]
# ![Model_output_A.png](attachment:52d22703-96f7-40e7-8ef4-b150753ab41d.png)

# %% [markdown]
# ![Model_output_B_(final_model).png](https://github.com/brigittesullivan/w12-statistical-modelling-project/blob/643beb8d3caf8ecdb4a7b06a1176b9e15479a99b/images/Model%20Output%20B%20(final%20model).png)

# %%
# Out:
#   Cell In[1], line 1
#     https://github.com/brigittesullivan/w12-statistical-modelling-project/blob/643beb8d3caf8ecdb4a7b06a1176b9e15479a99b/images/Model%20Output%20B%20(final%20model).png
#           ^
# SyntaxError: invalid syntax
